# %%
import mplfinance as mpf
import yfinance as yf
import pandas as pd
import ta
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# spy=yf.download('spy',period='30d',interval='5m')
# spy

# %%
spy=pd.read_csv('spy_3min.csv')

# %%
# read the data from the website
# colnames=['Datetime','Open','High','Low','Close','Volume']
# spy=pd.read_csv("SPY_intraday.csv",names=colnames)
# spy.index=pd.to_datetime(spy["Datetime"])
# spy.drop("Datetime",axis=1,inplace=True)

# %%
spy
# Out:
#         Unnamed: 0             Datetime      Open      High       Low  \
# 0                0  2005-01-03 08:30:00   87.0682   87.0753   87.0682
# 1                1  2005-01-03 08:33:00   87.0682   87.0896   87.0682
# 2                2  2005-01-03 08:36:00   87.0467   87.0467   87.0467
# 3                3  2005-01-03 08:39:00       NaN       NaN       NaN
# 4                4  2005-01-03 08:42:00   87.0467   87.0467   87.0395
# ...            ...                  ...       ...       ...       ...
# 674405      674405  2022-11-11 15:45:00  398.7900  399.0400  398.6800
# 674406      674406  2022-11-11 15:48:00  398.8700  399.3500  398.7700
# 674407      674407  2022-11-11 15:51:00  399.0900  399.2100  398.5700
# 674408      674408  2022-11-11 15:54:00  399.1000  399.1300  398.3450
# 674409      674409  2022-11-11 15:57:00  398.4400  398.6300  398.1600
#
#            Close   Volume
# 0        87.0682   193500
# 1        87.0753    83500
# 2        87.0467     2000
# ...

# %%
spy.drop(spy.columns[0],axis=1,inplace=True)

# %%
spy
# Out:
#                    Datetime      Open      High       Low     Close   Volume
# 0       2005-01-03 08:30:00   87.0682   87.0753   87.0682   87.0682   193500
# 1       2005-01-03 08:33:00   87.0682   87.0896   87.0682   87.0753    83500
# 2       2005-01-03 08:36:00   87.0467   87.0467   87.0467   87.0467     2000
# 3       2005-01-03 08:39:00       NaN       NaN       NaN       NaN        0
# 4       2005-01-03 08:42:00   87.0467   87.0467   87.0395   87.0395     1600
# ...                     ...       ...       ...       ...       ...      ...
# 674405  2022-11-11 15:45:00  398.7900  399.0400  398.6800  398.8800  1298978
# 674406  2022-11-11 15:48:00  398.8700  399.3500  398.7700  399.0800  1184563
# 674407  2022-11-11 15:51:00  399.0900  399.2100  398.5700  399.1100  1198641
# 674408  2022-11-11 15:54:00  399.1000  399.1300  398.3450  398.4400  1420071
# 674409  2022-11-11 15:57:00  398.4400  398.6300  398.1600  398.5000  3396674
#
# [674410 rows x 6 columns]

# %%
spy.index=pd.to_datetime(spy["Datetime"])
spy.drop("Datetime",axis=1,inplace=True)

# %%
spy
# Out:
#                          Open      High       Low     Close   Volume
# Datetime
# 2005-01-03 08:30:00   87.0682   87.0753   87.0682   87.0682   193500
# 2005-01-03 08:33:00   87.0682   87.0896   87.0682   87.0753    83500
# 2005-01-03 08:36:00   87.0467   87.0467   87.0467   87.0467     2000
# 2005-01-03 08:39:00       NaN       NaN       NaN       NaN        0
# 2005-01-03 08:42:00   87.0467   87.0467   87.0395   87.0395     1600
# ...                       ...       ...       ...       ...      ...
# 2022-11-11 15:45:00  398.7900  399.0400  398.6800  398.8800  1298978
# 2022-11-11 15:48:00  398.8700  399.3500  398.7700  399.0800  1184563
# 2022-11-11 15:51:00  399.0900  399.2100  398.5700  399.1100  1198641
# 2022-11-11 15:54:00  399.1000  399.1300  398.3450  398.4400  1420071
# 2022-11-11 15:57:00  398.4400  398.6300  398.1600  398.5000  3396674
#
# [674410 rows x 5 columns]

# %%
#spy1=yf.download('spy',start='2022-11-12',end='2022-11-15',interval='5m')
#spy1

# %%
spy.loc['2022-11-04']
# Out:
#                        Open     High      Low    Close   Volume
# Datetime
# 2022-11-04 08:30:00  373.45  374.500  368.990  372.860   984907
# 2022-11-04 08:33:00  372.85  374.000  371.920  373.930   313237
# 2022-11-04 08:36:00  373.94  375.540  373.920  374.210   322563
# 2022-11-04 08:39:00  374.20  374.230  373.000  373.000   167871
# 2022-11-04 08:42:00  373.04  373.570  372.430  373.290   118161
# ...                     ...      ...      ...      ...      ...
# 2022-11-04 15:45:00  375.82  376.410  375.730  375.890  1329092
# 2022-11-04 15:48:00  375.89  376.045  375.120  375.185   965135
# 2022-11-04 15:51:00  375.18  375.400  374.935  375.310  1070863
# 2022-11-04 15:54:00  375.31  375.850  375.200  375.790  1063531
# 2022-11-04 15:57:00  375.79  376.470  375.400  376.340  3938845
#
# [150 rows x 5 columns]

# %%
spy=spy['2020']
# Out:
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/3591699513.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   spy=spy['2020']

# %%
spy["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
spy
# Out:
#                          Open      High       Low     Close   Volume
# Datetime
# 2020-01-02 08:30:00  309.9507  309.9889  309.9507  309.9889     9041
# 2020-01-02 08:33:00  309.9889  310.0272  309.9889  309.9985     5069
# 2020-01-02 08:36:00  310.0177  310.0177  309.9411  309.9411    14482
# 2020-01-02 08:39:00  309.9411  310.0559  309.9411  310.0559    38160
# 2020-01-02 08:42:00  310.0655  310.1325  310.0655  310.1229    21801
# ...                       ...       ...       ...       ...      ...
# 2020-12-31 15:45:00  364.0715  364.2568  364.0423  364.2051  1081997
# 2020-12-31 15:48:00  364.2032  364.9591  364.1983  364.7543  2953883
# 2020-12-31 15:51:00  364.7445  365.0176  364.6372  364.9493  2124014
# 2020-12-31 15:54:00  364.9591  365.0469  364.6372  365.0353  3225138
# 2020-12-31 15:57:00  365.0371  365.4273  364.6177  364.6372  6515793
#
# [37949 rows x 5 columns]

# %%
#mpf.plot(spy.loc['2022-11-04'],type='candle',mav=(9,21))

# %%
spy["adx"]=ta.trend.adx(spy["High"],spy["Low"],spy["Close"])
spy["di_plus"]=ta.trend.adx_neg(spy["High"],spy["Low"],spy["Close"])
spy["di_minus"]=ta.trend.adx_pos(spy["High"],spy["Low"],spy["Close"])
spy["ema_9"]=ta.trend.EMAIndicator(spy["Close"],5).ema_indicator()
spy["ema_21"]=ta.trend.EMAIndicator(spy["Close"],21).ema_indicator()
# Out:
# /Users/bikenkc/opt/anaconda3/lib/python3.9/site-packages/ta/trend.py:780: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /Users/bikenkc/opt/anaconda3/lib/python3.9/site-packages/ta/trend.py:785: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/398754540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["adx"]=ta.trend.adx(spy["High"],spy["Low"],spy["Close"])
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/398754540.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
spy.di_minus
# Out:
# Datetime
# 2020-01-02 08:30:00    0.0
# 2020-01-02 08:33:00    0.0
# 2020-01-02 08:36:00    0.0
# 2020-01-02 08:39:00    0.0
# 2020-01-02 08:42:00    0.0
#                       ...
# 2020-12-31 15:45:00    NaN
# 2020-12-31 15:48:00    NaN
# 2020-12-31 15:51:00    NaN
# 2020-12-31 15:54:00    NaN
# 2020-12-31 15:57:00    NaN
# Name: di_minus, Length: 37949, dtype: float64

# %%
spy.di_plus
# Out:
# Datetime
# 2020-01-02 08:30:00    0.0
# 2020-01-02 08:33:00    0.0
# 2020-01-02 08:36:00    0.0
# 2020-01-02 08:39:00    0.0
# 2020-01-02 08:42:00    0.0
#                       ...
# 2020-12-31 15:45:00    NaN
# 2020-12-31 15:48:00    NaN
# 2020-12-31 15:51:00    NaN
# 2020-12-31 15:54:00    NaN
# 2020-12-31 15:57:00    NaN
# Name: di_plus, Length: 37949, dtype: float64

# %%
spy.adx
# Out:
# Datetime
# 2020-01-02 08:30:00    0.0
# 2020-01-02 08:33:00    0.0
# 2020-01-02 08:36:00    0.0
# 2020-01-02 08:39:00    0.0
# 2020-01-02 08:42:00    0.0
#                       ...
# 2020-12-31 15:45:00    NaN
# 2020-12-31 15:48:00    NaN
# 2020-12-31 15:51:00    NaN
# 2020-12-31 15:54:00    NaN
# 2020-12-31 15:57:00    NaN
# Name: adx, Length: 37949, dtype: float64

# %%
spy["ema_9"]
# Out:
# Datetime
# 2020-01-02 08:30:00           NaN
# 2020-01-02 08:33:00           NaN
# 2020-01-02 08:36:00           NaN
# 2020-01-02 08:39:00           NaN
# 2020-01-02 08:42:00    310.042322
#                           ...
# 2020-12-31 15:45:00    364.150596
# 2020-12-31 15:48:00    364.351831
# 2020-12-31 15:51:00    364.550987
# 2020-12-31 15:54:00    364.712425
# 2020-12-31 15:57:00    364.687350
# Name: ema_9, Length: 37949, dtype: float64

# %%
spy["ema_21"]
# Out:
# Datetime
# 2020-01-02 08:30:00           NaN
# 2020-01-02 08:33:00           NaN
# 2020-01-02 08:36:00           NaN
# 2020-01-02 08:39:00           NaN
# 2020-01-02 08:42:00           NaN
#                           ...
# 2020-12-31 15:45:00    363.976716
# 2020-12-31 15:48:00    364.047405
# 2020-12-31 15:51:00    364.129396
# 2020-12-31 15:54:00    364.211751
# 2020-12-31 15:57:00    364.250428
# Name: ema_21, Length: 37949, dtype: float64

# %% [markdown]
# plt.plot(spy.loc["2022-11-11"]["ema_9"])
# plt.plot(spy.loc["2022-11-11"]["ema_21"],c='r')
# plt.xticks(rotation=45)

# %% [markdown]
# plt.plot(spy.loc["2022-11-11"]["di_plus"],c='r')
# plt.plot(spy.loc["2022-11-11"]["di_minus"],c='g')

# %%
def gain_plot(adx_plus_value,adx_minus_value):
    signal_list=[]
    signal=""
    return_list=[]
    for i in range(len(spy)):
        if spy.index[i].hour==15 and spy.index[i].minute==57:
            if signal=="Buy Call":
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            elif signal=="Buy Put":
                signal_list.append("Sell")
                signal=""
                return_list.append(cost-spy["Close"][i])
            elif signal=="":
                signal_list.append("")
                return_list.append(0)
        elif signal=="":
            if spy["di_plus"][i]>adx_plus_value and (spy["ema_9"][i]>spy["ema_21"][i]):
                signal="Buy Call"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            elif spy["di_minus"][i]>adx_minus_value and (spy["ema_21"][i]>spy["ema_9"][i]):
                signal="Buy Put"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            else:
                signal_list.append("")
                return_list.append(0)
        elif signal=="Buy Call":
            #sell signal
            if spy["di_plus"][i]<20:
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            else:
                signal_list.append("")
                return_list.append(0)

        elif signal=="Buy Put":
            #sell signal
            if spy["di_minus"][i]<20:
                signal_list.append("Sell")
                signal=""
                return_list.append(cost-spy["Close"][i])
            else:
                signal_list.append("")
                return_list.append(0)

    spy["signal"]=signal_list
    spy["return"]=return_list
    spy['cum_return']=spy['return'].cumsum()
    return spy["cum_return"].plot()

# %%
def gain_plot_combination(buy_adx_plus,buy_adx_minus,sell_adx_plus,sell_adx_minus):
    signal_list=[]
    signal=""
    return_list=[]
    for i in range(len(spy)):
        if spy.index[i].hour==15 and spy.index[i].minute==55:
            if signal=="Buy Call":
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            elif signal=="Buy Put":
                signal_list.append("Sell")
                signal=""
                return_list.append(cost-spy["Close"][i])
            elif signal=="":
                signal_list.append("")
                return_list.append(0)
        elif signal=="":
            if spy["di_plus"][i]>buy_adx_plus and (spy["ema_9"][i]>spy["ema_21"][i]):
                signal="Buy Call"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            elif spy["di_minus"][i]>buy_adx_minus and (spy["ema_21"][i]>spy["ema_9"][i]):
                signal="Buy Put"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            else:
                signal_list.append("")
                return_list.append(0)
        elif signal=="Buy Call":
            #sell signal
            if spy["di_plus"][i]<sell_adx_plus:
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            else:
                signal_list.append("")
                return_list.append(0)

        elif signal=="Buy Put":
            #sell signal
            if spy["di_minus"][i]<sell_adx_minus:
                signal_list.append("Sell")
                signal=""
                return_list.append(cost-spy["Close"][i])
            else:
                signal_list.append("")
                return_list.append(0)

    spy["signal"]=signal_list
    spy["return"]=return_list
    spy['cum_return']=spy['return'].cumsum()
    return spy["cum_return"].plot()

# %%
def gain_plot_combination_return(buy_adx_plus,buy_adx_minus,sell_adx_plus,sell_adx_minus):
    signal_list=[]
    signal=""
    return_list=[]
    for i in range(len(spy)):
        if spy.index[i].hour==15 and spy.index[i].minute==55:
            if signal=="Buy Call":
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            elif signal=="Buy Put":
                signal_list.append("Sell")
                signal=""
                return_list.append(cost-spy["Close"][i])
            elif signal=="":
                signal_list.append("")
                return_list.append(0)
        elif signal=="":
            if spy["di_plus"][i]>buy_adx_plus and (spy["ema_9"][i]>spy["ema_21"][i]):
                signal="Buy Call"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            elif spy["di_minus"][i]>buy_adx_minus and (spy["ema_21"][i]>spy["ema_9"][i]):
                signal="Buy Put"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            else:
                signal_list.append("")
                return_list.append(0)
        elif signal=="Buy Call":
            #sell signal
            if spy["di_plus"][i]<sell_adx_plus:
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            else:
                signal_list.append("")
                return_list.append(0)

        elif signal=="Buy Put":
            #sell signal
            if spy["di_minus"][i]<sell_adx_minus:
                signal_list.append("Sell")
                signal=""
                return_list.append(cost-spy["Close"][i])
            else:
                signal_list.append("")
                return_list.append(0)

    spy["signal"]=signal_list
    spy["return"]=return_list
    spy['cum_return']=spy['return'].cumsum()
    return spy['cum_return'].iloc[-1]

# %%
gain_plot_combination(buy_adx_plus=30,buy_adx_minus=20,sell_adx_plus=25,sell_adx_minus=20)
#gain_plot_combination(buy_adx_plus=30,buy_adx_minus=25,sell_adx_plus=20,sell_adx_minus=20)
#gain_plot_combination(buy_adx_plus=20,buy_adx_minus=25,sell_adx_plus=20,sell_adx_minus=20)
#gain_plot_combination(buy_adx_plus=25,buy_adx_minus=25,sell_adx_plus=20,sell_adx_minus=20)
#gain_plot_combination(buy_adx_plus=30,buy_adx_minus=30,sell_adx_plus=20,sell_adx_minus=20)
#gain_plot_combination(buy_adx_plus=25,buy_adx_minus=30,sell_adx_plus=25,sell_adx_minus=25)
# Out:
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/3606989055.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/3606989055.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/3606989055.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
cum_return=[]
parameters=[]
for i in range(20,31):
    for j in range(20,31):
        parameters.append((i,j))
        cum_return.append(gain_plot_combination_return(buy_adx_plus=i,buy_adx_minus=j,sell_adx_plus=20,sell_adx_minus=20))
# Out:
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/290209259.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/290209259.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/290209259.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_parameter_3min=pd.DataFrame(columns=['parameter','cum_return'])
df_parameter_3min
# Out:
# Empty DataFrame
# Columns: [parameter, cum_return]
# Index: []

# %%
df_parameter_3min["parameter"]=parameters
df_parameter_3min["cum_return"]=cum_return

# %%
df_parameter_3min
# Out:
#     parameter  cum_return
# 0    (20, 20)    -59.9400
# 1    (20, 21)    -49.4602
# 2    (20, 22)    -52.5004
# 3    (20, 23)    -56.4941
# 4    (20, 24)     36.8236
# ..        ...         ...
# 116  (30, 26)      6.1305
# 117  (30, 27)      0.5144
# 118  (30, 28)      1.5692
# 119  (30, 29)      0.3156
# 120  (30, 30)     -3.1298
#
# [121 rows x 2 columns]

# %%
df_parameter_3min.sort_values(by=['cum_return'],ascending=False)
# Out:
#    parameter  cum_return
# 4   (20, 24)     36.8236
# 37  (23, 24)     36.4714
# 26  (22, 24)     35.3762
# 15  (21, 24)     35.1201
# 48  (24, 24)     31.2512
# ..       ...         ...
# 91  (28, 23)    -64.3703
# 66  (26, 20)    -64.6228
# 55  (25, 20)    -64.7759
# 57  (25, 22)    -65.3709
# 58  (25, 23)    -66.4991
#
# [121 rows x 2 columns]

# %%
df_parameter_3min.to_csv("PARAMETERS_Combination_ADX_ema_5_21_crossover.csv")

# %%
# for i in range(20,31):
#     for j in range(20,31):
#         gain_plot(i,j)

# %%
for i in range(20,31):
    for j in range(20,31):
        gain_plot_combination(buy_adx_plus=i,buy_adx_minus=j,sell_adx_plus=20,sell_adx_minus=20)
# Out:
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/3606989055.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/3606989055.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_44013/3606989055.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
spy.to_csv("ADX_ema_9_21_crossover.csv")

# %%
spy

# %%
gain_plot_combination(buy_adx_plus=28,buy_adx_minus=22,sell_adx_plus=20,sell_adx_minus=20)
