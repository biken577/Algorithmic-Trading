# %%
import mplfinance as mpf
import yfinance as yf
import pandas as pd
import ta
import matplotlib.pyplot as plt

# %%
# spy=yf.download('spy',period='30d',interval='5m')
# spy

# %%
# read the data from the website
# colnames=['Datetime','Open','High','Low','Close','Volume']
# spy=pd.read_csv("SPY_intraday.csv",names=colnames)
# spy.index=pd.to_datetime(spy["Datetime"])
# spy.drop("Datetime",axis=1,inplace=True)

# %%
colnames=['Datetime','Open','High','Low','Close','Volume']
spy=pd.read_csv("SPY_1min.txt",names=colnames)

# %%
spy
# Out:
#                     Datetime      Open      High       Low     Close  Volume
# 0        2005-01-03 08:00:00   87.0896   87.0896   87.0896   87.0896   21400
# 1        2005-01-03 08:01:00   87.0467   87.0467   87.0467   87.0467    1000
# 2        2005-01-03 08:02:00   87.0467   87.0467   87.0467   87.0467    1500
# 3        2005-01-03 08:03:00   87.0538   87.0610   87.0538   87.0610     600
# 4        2005-01-03 08:04:00   87.0538   87.0538   87.0538   87.0538     100
# ...                      ...       ...       ...       ...       ...     ...
# 3277869  2022-11-11 19:54:00  398.5100  398.5100  398.5100  398.5100     101
# 3277870  2022-11-11 19:55:00  398.5100  398.5100  398.5000  398.5000    1814
# 3277871  2022-11-11 19:56:00  398.5100  398.5200  398.5100  398.5200    1360
# 3277872  2022-11-11 19:57:00  398.5300  398.5300  398.5300  398.5300    1100
# 3277873  2022-11-11 19:59:00  398.5300  398.5300  398.5100  398.5100     695
#
# [3277874 rows x 6 columns]

# %%
spy.index=pd.to_datetime(spy["Datetime"])

# %%
spy.drop("Datetime",axis=1,inplace=True)

# %%
spy
# Out:
#                          Open      High       Low     Close  Volume
# Datetime
# 2005-01-03 08:00:00   87.0896   87.0896   87.0896   87.0896   21400
# 2005-01-03 08:01:00   87.0467   87.0467   87.0467   87.0467    1000
# 2005-01-03 08:02:00   87.0467   87.0467   87.0467   87.0467    1500
# 2005-01-03 08:03:00   87.0538   87.0610   87.0538   87.0610     600
# 2005-01-03 08:04:00   87.0538   87.0538   87.0538   87.0538     100
# ...                       ...       ...       ...       ...     ...
# 2022-11-11 19:54:00  398.5100  398.5100  398.5100  398.5100     101
# 2022-11-11 19:55:00  398.5100  398.5100  398.5000  398.5000    1814
# 2022-11-11 19:56:00  398.5100  398.5200  398.5100  398.5200    1360
# 2022-11-11 19:57:00  398.5300  398.5300  398.5300  398.5300    1100
# 2022-11-11 19:59:00  398.5300  398.5300  398.5100  398.5100     695
#
# [3277874 rows x 5 columns]

# %%
#spy1=yf.download('spy',start='2022-11-12',end='2022-11-15',interval='5m')
#spy1

# %%
spy.loc['2022-11-04']
# Out:
#                        Open      High     Low     Close  Volume
# Datetime
# 2022-11-04 04:00:00  371.76  371.9700  371.50  371.9700    1498
# 2022-11-04 04:01:00  371.92  372.1000  371.92  371.9200    6532
# 2022-11-04 04:02:00  371.97  372.2300  371.97  372.2300     970
# 2022-11-04 04:03:00  372.20  372.2000  372.16  372.1600     426
# 2022-11-04 04:04:00  372.02  372.2100  372.02  372.2100     421
# ...                     ...       ...     ...       ...     ...
# 2022-11-04 19:52:00  375.94  375.9500  375.94  375.9500    1060
# 2022-11-04 19:54:00  375.97  375.9800  375.95  375.9800    4536
# 2022-11-04 19:56:00  375.99  375.9900  375.99  375.9900     500
# 2022-11-04 19:58:00  375.90  375.9399  375.82  375.9399    1200
# 2022-11-04 19:59:00  375.94  376.0000  375.83  376.0000    2349
#
# [828 rows x 5 columns]

# %%
spy=spy['2022']
# Out:
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/227794539.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   spy=spy['2022']

# %%
spy
# Out:
#                          Open      High       Low     Close  Volume
# Datetime
# 2022-01-03 04:00:00  470.9116  471.4454  470.9116  471.1983    7079
# 2022-01-03 04:01:00  471.1983  471.1983  471.1983  471.1983     108
# 2022-01-03 04:02:00  471.1587  471.1587  471.1291  471.1291     210
# 2022-01-03 04:03:00  471.1093  471.1093  471.0105  471.0895     400
# 2022-01-03 04:04:00  471.0302  471.0895  471.0302  471.0895     200
# ...                       ...       ...       ...       ...     ...
# 2022-11-11 19:54:00  398.5100  398.5100  398.5100  398.5100     101
# 2022-11-11 19:55:00  398.5100  398.5100  398.5000  398.5000    1814
# 2022-11-11 19:56:00  398.5100  398.5200  398.5100  398.5200    1360
# 2022-11-11 19:57:00  398.5300  398.5300  398.5300  398.5300    1100
# 2022-11-11 19:59:00  398.5300  398.5300  398.5100  398.5100     695
#
# [188173 rows x 5 columns]

# %%
mpf.plot(spy.loc['2022-11-04'],type='candle',mav=(9,21))
# Out:
# /Users/bikenkc/opt/anaconda3/lib/python3.9/site-packages/mplfinance/_arg_validators.py:36: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
spy["adx"]=ta.trend.adx(spy["High"],spy["Low"],spy["Close"])
spy["di_plus"]=ta.trend.adx_neg(spy["High"],spy["Low"],spy["Close"])
spy["di_minus"]=ta.trend.adx_pos(spy["High"],spy["Low"],spy["Close"])
spy["ema_9"]=ta.trend.EMAIndicator(spy["Close"],9).ema_indicator()
spy["ema_21"]=ta.trend.EMAIndicator(spy["Close"],21).ema_indicator()
# Out:
# /Users/bikenkc/opt/anaconda3/lib/python3.9/site-packages/ta/trend.py:780: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /Users/bikenkc/opt/anaconda3/lib/python3.9/site-packages/ta/trend.py:785: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/1447071527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["adx"]=ta.trend.adx(spy["High"],spy["Low"],spy["Close"])
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/1447071527.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["di_plus"]=ta.trend.adx_neg(spy["High"],spy["Low"],spy["Close"])
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/1447071527.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["di_minus"]=ta.trend.adx_pos(spy["High"],spy["Low"],spy["Close"])
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/1447071527.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["ema_9"]=ta.trend.EMAIndicator(spy["Close"],9).ema_indicator()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/1447071527.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["ema_21"]=ta.trend.EMAIndicator(spy["Close"],21).ema_indicator()

# %%
spy.di_minus
# Out:
# Datetime
# 2022-01-03 04:00:00     0.000000
# 2022-01-03 04:01:00     0.000000
# 2022-01-03 04:02:00     0.000000
# 2022-01-03 04:03:00     0.000000
# 2022-01-03 04:04:00     0.000000
#                          ...
# 2022-11-11 19:54:00    39.993789
# 2022-11-11 19:55:00    38.902215
# 2022-11-11 19:56:00    39.518389
# 2022-11-11 19:57:00    41.274094
# 2022-11-11 19:59:00    38.845350
# Name: di_minus, Length: 188173, dtype: float64

# %%
spy.di_plus
# Out:
# Datetime
# 2022-01-03 04:00:00     0.000000
# 2022-01-03 04:01:00     0.000000
# 2022-01-03 04:02:00     0.000000
# 2022-01-03 04:03:00     0.000000
# 2022-01-03 04:04:00     0.000000
#                          ...
# 2022-11-11 19:54:00    49.817549
# 2022-11-11 19:55:00    51.187208
# 2022-11-11 19:56:00    48.345179
# 2022-11-11 19:57:00    46.941780
# 2022-11-11 19:59:00    50.063952
# Name: di_plus, Length: 188173, dtype: float64

# %%
spy.adx
# Out:
# Datetime
# 2022-01-03 04:00:00     0.000000
# 2022-01-03 04:01:00     0.000000
# 2022-01-03 04:02:00     0.000000
# 2022-01-03 04:03:00     0.000000
# 2022-01-03 04:04:00     0.000000
#                          ...
# 2022-11-11 19:54:00    10.415430
# 2022-11-11 19:55:00    10.645502
# 2022-11-11 19:56:00    10.602682
# 2022-11-11 19:57:00    10.304261
# 2022-11-11 19:59:00    10.469530
# Name: adx, Length: 188173, dtype: float64

# %%
spy["ema_9"]
# Out:
# Datetime
# 2022-01-03 04:00:00           NaN
# 2022-01-03 04:01:00           NaN
# 2022-01-03 04:02:00           NaN
# 2022-01-03 04:03:00           NaN
# 2022-01-03 04:04:00           NaN
#                           ...
# 2022-11-11 19:54:00    398.525874
# 2022-11-11 19:55:00    398.520699
# 2022-11-11 19:56:00    398.520559
# 2022-11-11 19:57:00    398.522447
# 2022-11-11 19:59:00    398.519958
# Name: ema_9, Length: 188173, dtype: float64

# %%
spy["ema_21"]
# Out:
# Datetime
# 2022-01-03 04:00:00           NaN
# 2022-01-03 04:01:00           NaN
# 2022-01-03 04:02:00           NaN
# 2022-01-03 04:03:00           NaN
# 2022-01-03 04:04:00           NaN
#                           ...
# 2022-11-11 19:54:00    398.529616
# 2022-11-11 19:55:00    398.526924
# 2022-11-11 19:56:00    398.526294
# 2022-11-11 19:57:00    398.526631
# 2022-11-11 19:59:00    398.525119
# Name: ema_21, Length: 188173, dtype: float64

# %%
plt.plot(spy.loc["2022-11-11"]["ema_9"])
plt.plot(spy.loc["2022-11-11"]["ema_21"],c='r')
plt.xticks(rotation=45)
# Out:
# (array([19307.16666667, 19307.25      , 19307.33333333, 19307.41666667,
#         19307.5       , 19307.58333333, 19307.66666667, 19307.75      ,
#         19307.83333333]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(spy.loc["2022-11-11"]["di_plus"],c='r')
plt.plot(spy.loc["2022-11-11"]["di_minus"],c='g')

# %%
def gain_plot_data(adx_plus_value,adx_minus_value):
    signal_list=[]
    signal=""
    return_list=[]
    for i in range(len(spy)):
        if spy.index[i].hour==15 and spy.index[i].minute==55:
            if signal=="Buy Call":
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            elif signal=="Buy Put":
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            elif signal=="":
                signal_list.append("")
                return_list.append(0)
        elif signal=="":
            if spy["di_plus"][i]>adx_plus_value and (spy["ema_9"][i]>spy["ema_21"][i]):
                signal="Buy Call"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            elif spy["di_minus"][i]>adx_minus_value and (spy["ema_21"][i]>spy["ema_9"][i]):
                signal="Buy Put"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            else:
                signal_list.append("")
                return_list.append(0)
        elif signal=="Buy Call":
            #sell signal
            if spy["di_plus"][i]<20:
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            else:
                signal_list.append("")
                return_list.append(0)

        elif signal=="Buy Put":
            #sell signal
            if spy["di_minus"][i]<20:
                signal_list.append("Sell")
                signal=""
                return_list.append(cost-spy["Close"][i])
            else:
                signal_list.append("")
                return_list.append(0)

    spy["signal"]=signal_list
    spy["return"]=return_list
    spy['cum_return']=spy['return'].cumsum()
    return spy

# %%
def gain_plot_combination(buy_adx_plus,buy_adx_minus,sell_adx_plus,sell_adx_minus):
    signal_list=[]
    signal=""
    return_list=[]
    for i in range(len(spy)):
        if spy.index[i].hour==15 and spy.index[i].minute==55:
            if signal=="Buy Call":
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            elif signal=="Buy Put":
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            elif signal=="":
                signal_list.append("")
                return_list.append(0)
        elif signal=="":
            if spy["di_plus"][i]>buy_adx_plus and (spy["ema_9"][i]>spy["ema_21"][i]):
                signal="Buy Call"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            elif spy["di_minus"][i]>buy_adx_minus and (spy["ema_21"][i]>spy["ema_9"][i]):
                signal="Buy Put"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            else:
                signal_list.append("")
                return_list.append(0)
        elif signal=="Buy Call":
            #sell signal
            if spy["di_plus"][i]<sell_adx_plus:
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            else:
                signal_list.append("")
                return_list.append(0)

        elif signal=="Buy Put":
            #sell signal
            if spy["di_minus"][i]<sell_adx_minus:
                signal_list.append("Sell")
                signal=""
                return_list.append(cost-spy["Close"][i])
            else:
                signal_list.append("")
                return_list.append(0)

    spy["signal"]=signal_list
    spy["return"]=return_list
    spy['cum_return']=spy['return'].cumsum()
    return spy["cum_return"].plot()

# %%
def gain_plot_combination_return(buy_adx_plus,buy_adx_minus,sell_adx_plus,sell_adx_minus):
    signal_list=[]
    signal=""
    return_list=[]
    for i in range(len(spy)):
        if spy.index[i].hour==15 and spy.index[i].minute==55:
            if signal=="Buy Call":
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            elif signal=="Buy Put":
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            elif signal=="":
                signal_list.append("")
                return_list.append(0)
        elif signal=="":
            if spy["di_plus"][i]>buy_adx_plus and (spy["ema_9"][i]>spy["ema_21"][i]):
                signal="Buy Call"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            elif spy["di_minus"][i]>buy_adx_minus and (spy["ema_21"][i]>spy["ema_9"][i]):
                signal="Buy Put"
                signal_list.append(signal)
                cost=spy["Close"][i]
                return_list.append(0)
            else:
                signal_list.append("")
                return_list.append(0)
        elif signal=="Buy Call":
            #sell signal
            if spy["di_plus"][i]<sell_adx_plus:
                signal_list.append("Sell")
                signal=""
                return_list.append(spy["Close"][i]-cost)
            else:
                signal_list.append("")
                return_list.append(0)

        elif signal=="Buy Put":
            #sell signal
            if spy["di_minus"][i]<sell_adx_minus:
                signal_list.append("Sell")
                signal=""
                return_list.append(cost-spy["Close"][i])
            else:
                signal_list.append("")
                return_list.append(0)

    spy["signal"]=signal_list
    spy["return"]=return_list
    spy['cum_return']=spy['return'].cumsum()
    return spy['cum_return'].iloc[-1]

# %% [markdown]
# # Finding best parameters

# %%
cum_return=[]
parameters=[]
for i in range(20,31):
    for j in range(20,31):
        for k in range(20,31):
            for l in range(20,31):
                parameters.append((i,j,k,l))
                cum_return.append(gain_plot_combination_return(buy_adx_plus=i,buy_adx_minus=j,sell_adx_plus=k,sell_adx_minus=l))
# Out:
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_21802/3629531360.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_21802/3629531360.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_21802/3629531360.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()

# %%
df_parameter=pd.DataFrame(columns=['parameter','cum_return'])
df_parameter
# Out:
# Empty DataFrame
# Columns: [parameter, cum_return]
# Index: []

# %%
df_parameter["parameter"]=parameters
df_parameter["cum_return"]=cum_return

# %%
df_parameter
# Out:
#               parameter  cum_return
# 0      (20, 20, 20, 20)     73.3740
# 1      (20, 20, 20, 21)     -0.3855
# 2      (20, 20, 20, 22)    -35.2246
# 3      (20, 20, 20, 23)    -67.6573
# 4      (20, 20, 20, 24)    -85.6994
# ...                 ...         ...
# 14636  (30, 30, 30, 26)    -12.4011
# 14637  (30, 30, 30, 27)    -13.4652
# 14638  (30, 30, 30, 28)    -17.4434
# 14639  (30, 30, 30, 29)    -16.9968
# 14640  (30, 30, 30, 30)     -6.5592
#
# [14641 rows x 2 columns]

# %%
df_parameter.sort_values(by=['cum_return'],ascending=False)
# Out:
#               parameter  cum_return
# 10692  (28, 20, 24, 20)    211.8275
# 13409  (30, 20, 29, 20)    210.7134
# 13398  (30, 20, 28, 20)    210.0054
# 12089  (29, 20, 30, 20)    209.8262
# 13420  (30, 20, 30, 20)    209.6376
# ...                 ...         ...
# 250    (20, 22, 20, 28)   -131.7242
# 20     (20, 20, 21, 29)   -133.3490
# 19     (20, 20, 21, 28)   -135.0333
# 9      (20, 20, 20, 29)   -137.7066
# 8      (20, 20, 20, 28)   -139.8917
#
# [14641 rows x 2 columns]

# %%
df_parameter.to_csv("PARAMETERS_Combination_ADX_ema_9_21_crossover.csv")

# %%
for i in range(20,31):
    for j in range(20,31):
        gain_plot_combination(buy_adx_plus=i,buy_adx_minus=j,sell_adx_plus=20,sell_adx_minus=20)
# Out:
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_38979/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()

# %%
for i in range(20,31):
    for j in range(20,31):
        for k in range(20,31):
            for l in range(20,31):
                gain_plot_combination(buy_adx_plus=i,buy_adx_minus=j,sell_adx_plus=k,sell_adx_minus=l)

# %%
for i in range(25,30):
    gain_plot_combination(buy_adx_plus=30,buy_adx_minus=20,sell_adx_plus=i,sell_adx_minus=20)
# Out:
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3881027163.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()

# %%
gain_plot_data(30,20).to_csv('5min_adx.csv')
# Out:
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3230077991.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["signal"]=signal_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3230077991.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["return"]=return_list
# /var/folders/0d/2q3_g9bj7tn1m1t1w5crmtvh0000gn/T/ipykernel_31698/3230077991.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['cum_return']=spy['return'].cumsum()
